# %% [markdown]
# # Headings

# %% [markdown]
# # Heading 1
# # Heading 2
# ## Heading 2.1
# ## Heading 2.2

# %% [markdown]
# # font

# %% [markdown]
# **Bold Font** or __Bold Font__
#
# *Italic* or _Italic Font_
#
# <u> underline </u>

# %% [markdown]
# # Text color

# %% [markdown]
# <font color=blue|red|green|pink|yellow>Text</font>

# %% [markdown]
# # list

# %% [markdown]
# - CS
# - EE
#  - signals
#  - systems

# %% [markdown]
# 1. CS
# 2. EE
#  1. signals
#  2. systems

# %% [markdown]
# # Links

# %% [markdown]
# http://www.uvm.edu/

# %% [markdown]
# [UVM](http://www.uvm.edu/)

# %% [markdown]
# # Image

# %% [markdown]
# # ![moveinday2017_1200x524.jpg](attachment:moveinday2017_1200x524.jpg)

# %% [markdown]
# # Horizontal Line

# %% [markdown]
# ---

# %% [markdown]
# # Table

# %% [markdown]
# | Very          | Easy          | Way   |  to | make | tables |
# | ------------- |---------------| ------|-----|------|--------|
# | sample 1      | row 1         |  1    |  4  |   7  |   10   |
# | sample 2      | row 2         |  2    |  5  |   8  |   11   |
# | sample 3      | row 3         |  3    |  6  |   9  |   12   |

# %% [markdown]
# # HTML

# %% [markdown]
# <b>just</b> write <i>what</i> ever <span style="color:red;">HTML</span>  you <u>like</u>.

# %% [markdown]
# # Code

# %% [markdown]
# Python Code:
# ```python
# x = 5
# print "%.2f" % x
# ```

# %% [markdown]
# # LaTeX

# %% [markdown]
# You can use LaTeX in line by like this $y = x^2$ or in block like this
# $$y = x^2$$
# $$\sum\limits_{x=1}^{\infty} {1 \over x} = 2$$
# $$\prod\limits_{i=1}^{n} x_i - 1$$

# %% [markdown]
# # Calculus

# %% [markdown]
# $$\lim\limits_{x \to 0^+} {1 \over 0} = \inf$$
# $$\int\limits_a^b 2x \, dx$$

# %% [markdown]
# # Function definition over periods

# %% [markdown]
# $f(x) =
# \left\{
#     \begin{array}{ll}
#         0  & \mbox{if } x = 0 \\
#         {1 \over x} & \mbox{if } x \neq 0
#     \end{array}
# \right.$
